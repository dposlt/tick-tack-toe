# %%
def pole():
    print('''
        +----+----+----+
        |    |    |    |
        +----+----+----+
        |    |    |    | 
        +----+----+----+
        |    |    |    |
        +----+----+----+
    
    ''')
    
def vyberSymbol():
    while True:
        symbol = input('Vyber si svuj symbol x nebo O: ')
        
        # k porovnani retezcu musime pouzi equals, v pripade != porovnava objekt a ne obsah
        if symbol.__ne__('x') and symbol.__ne__('o'):
            print(f'symbol {symbol}, který jste vybrali neodpovídá možnostem')
        else:
            False
            return symbol.upper()

def menu():
    print('vloz svuj symbol do pole')
    print('''
            A1 = leva horni
            A2 = stredni horni
            A3 = prava horni
            B1 = leva stredni
            B2 = stred stredni
            B3 = prava stredni
            C1 = leva dolni
            C2 = stredni dolni
            C3 = prava dolni
            ''')
    volba = input()
    if volba == volba.lower():
        volba = volba.upper()
    
    return volba
    
def hra(symbol, volba):
    #pouzijeme if protoze case je mozne pouzit az od verze 3.10
    
    if volba == "A1":
        print(f'Symbol {symbol} na A1')
        print(f'''
        +----+----+----+
        | {symbol}  |    |    |
        +----+----+----+
        |    |    |    | 
        +----+----+----+
        |    |    |    |
        +----+----+----+
    
    ''')
    if volba == "A2":
        print(f'Symbol {symbol} na A2')
        print(f'''
        +----+----+----+
        |    | {symbol}  |    |
        +----+----+----+
        |    |    |    | 
        +----+----+----+
        |    |    |    |
        +----+----+----+
    
    ''')
    if volba == "A3":
        print(f'Symbol {symbol} na A3')
        print(f'''
        +----+----+----+
        |    |    | {symbol}  |
        +----+----+----+
        |    |    |    | 
        +----+----+----+
        |    |    |    |
        +----+----+----+
    
    ''')
        
    if volba == "B1":
        print(f'Symbol {symbol} na B1')
        print(f'''
        +----+----+----+
        |    |    |    |
        +----+----+----+
        | {symbol}  |    |    | 
        +----+----+----+
        |    |    |    |
        +----+----+----+
    
    ''')
    if volba == "B2":
        print(f'Symbol {symbol} na B2')
        print(f'''
        +----+----+----+
        |    |    |    |
        +----+----+----+
        |    | {symbol}  |    | 
        +----+----+----+
        |    |    |    |
        +----+----+----+
    
    ''')
    if volba == "B3":
        print(f'Symbol {symbol} na B3')
        print(f'''
        +----+----+----+
        |    |    |    |
        +----+----+----+
        |    |    | {symbol}  | 
        +----+----+----+
        |    |    |    |
        +----+----+----+
    
    ''')
    
    if volba == "C1":
        print(f'Symbol {symbol} na C1')
        print(f'''
        +----+----+----+
        |    |    |    |
        +----+----+----+
        |    |    |    | 
        +----+----+----+
        | {symbol}  |    |    |
        +----+----+----+
    
    ''')
    
    if volba == "C2":
        print(f'Symbol {symbol} na C2')
        print(f'''
        +----+----+----+
        |    |    |    |
        +----+----+----+
        |    |    |    | 
        +----+----+----+
        |    | {symbol}  |    |
        +----+----+----+
    
    ''')
    
    if volba == "C3":
        print(f'Symbol {symbol} na C3')
        print(f'''
        +----+----+----+
        |    |    |    |
        +----+----+----+
        |    |    |    | 
        +----+----+----+
        |    |    | {symbol}  |
        +----+----+----+
    
    ''')
    
    
    
    
if __name__ == '__main__':

    hra(vyberSymbol(), menu())
# Out:
# Vyber si svuj symbol x nebo O: x
# vloz svuj symbol do pole
#
#             A1 = leva horni
#             A2 = stredni horni
#             A3 = prava horni
#             B1 = leva stredni
#             B2 = stred stredni
#             B3 = prava stredni
#             C1 = leva dolni
#             C2 = stredni dolni
#             C3 = prava dolni
#
# a1
# Symbol X na A1
#
#         +----+----+----+
#         | X  |    |    |
#         +----+----+----+
#         |    |    |    |
#         +----+----+----+
#         |    |    |    |
#         +----+----+----+
